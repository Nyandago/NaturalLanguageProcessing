# %%
import spacy
nlp = spacy.load("en_core_web_sm")

doc = nlp("The cars are running faster than the previous race.")
lemmas = [(token.text, token.lemma_) for token in doc]

print(lemmas)
# Out:
# [('The', 'the'), ('cars', 'car'), ('are', 'be'), ('running', 'run'), ('faster', 'fast'), ('than', 'than'), ('the', 'the'), ('previous', 'previous'), ('race', 'race'), ('.', '.')]
