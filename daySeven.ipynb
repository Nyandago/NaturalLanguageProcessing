# %%
import spacy
nlp = spacy.load("en_core_web_sm")

doc = nlp("NLP makes computers understand human language.")
tags = [(token.text, token.pos_) for token in doc]

print(tags)
# Out:
# [('NLP', 'PROPN'), ('makes', 'VERB'), ('computers', 'NOUN'), ('understand', 'VERB'), ('human', 'ADJ'), ('language', 'NOUN'), ('.', 'PUNCT')]
