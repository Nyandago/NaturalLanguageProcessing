# %%
from gensim.models import Word2Vec

sentences = [
    ["nlp", "is", "fun"],
    ["machine", "learning", "is", "cool"],
    ["nlp", "and", "machine", "learning"]
]

model = Word2Vec(sentences, vector_size=50, min_count=1)

print(model.wv.most_similar("nlp"))
# Out:
# [('learning', -0.014483886770904064), ('fun', -0.04407675564289093), ('is', -0.15514613687992096), ('machine', -0.174241840839386), ('and', -0.20593705773353577), ('cool', -0.20909617841243744)]
