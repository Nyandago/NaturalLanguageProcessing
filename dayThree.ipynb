# %%
import nltk
from nltk import sent_tokenize

text = "Hello world. NLP is powerful. Let's learn more!"
sentences = sent_tokenize(text)

print(sentences)
# Out:
# ['Hello world.', 'NLP is powerful.', "Let's learn more!"]
